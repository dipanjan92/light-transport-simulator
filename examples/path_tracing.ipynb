# %% [markdown]
# # Path Tracing Notebook
# Implementation of Light Transport Algorithms

# %% [markdown]
# ********************************************************************************************

# %%
import os
os.chdir("..")
print(os.getcwd())
# Out:
# /Volumes/extssd/Projects/light-transport-simulator

# %%
import taichi as ti
ti.init(arch=ti.cpu, debug=True, random_seed=68739)
# Out:
# [Taichi] version 1.7.4, llvm 15.0.7, commit b4b956fd, osx, python 3.13.7
# [Taichi] Starting on arch=arm64
# [I 11/12/25 00:44:32.747 18174278] [shell.py:_shell_pop_print@23] Graphical python shell detected, using wrapped sys.stdout

# %%
import time
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
from taichi.math import vec3, cross, normalize, dot

# %%
cornell_box = "scenes/cornell-box.pbrt"
volumetric_caustic = "scenes/volumetric-caustic.pbrt"
door_scene = "scenes/veach/veach-ajar.pbrt"
testball ="scenes/material-testball/scene-v4.pbrt"
one = "scenes/one.pbrt"
cb = "scenes/cb.pbrt"
cb_spheres = "scenes/cb-spheres.pbrt"
cb_spheres_flipped = "scenes/cb-spheres-2.pbrt"
veach_mis = "scenes/veach-mis/scene-v4.pbrt"
rough_metal_spheres = "scenes/cb-rough-metal.pbrt"
test = "scenes/test.pbrt"


file_path = test

# %%
from primitives.primitives import Primitive

n_p = 1024
PS = ti.root.dense(ti.i, n_p)
primitives = Primitive.field()
PS.place(primitives)
# Out:
# <ti.SNode of type dense>

# %%
from pbrt.transformations import parse_transform
from pbrt.material_parser import parse_materials
from pbrt.shape_parser import extract_all_shapes, parse_shapes
from pbrt.parser import pbrt_to_dict

# Parse the scene
scene_dict = pbrt_to_dict(file_path)

# Get the Transform Matrix
global_transform = parse_transform(scene_dict["Transform"])

# Extract the shapes
shapes_list = extract_all_shapes(file_path)

# Parse the materials
materials = scene_dict.get("MakeNamedMaterial", [])
# parsed_materials = parse_materials(materials)

# Extract Primitives
n_primitives, light_count = parse_shapes(shapes_list, materials, primitives, global_transform)

# %%
n_primitives, light_count
# Out:
# (36, 2)

# %%
primitives[11].material.reflectance
# Out:
# [0.89999998 0.80000001 0.1       ]

# %%
from base.lights import DiffuseAreaLight

# Create a Taichi field for light sources
n_lights = light_count
LS = ti.root.dense(ti.i, n_lights)
lights = DiffuseAreaLight.field()
LS.place(lights)
# Out:
# <ti.SNode of type dense>

# %%
@ti.kernel
def populate_shapes():

    for i in range(n_primitives):

        # primitives[i].bsdf.diffuse.type = 0
        # primitives[i].bsdf.transmit.type = 1
        # primitives[i].bsdf.dielectric.type = 2
        # primitives[i].bsdf.conductor.type = 3

        material = primitives[i].material

        if material.material_type==0:
            # Diffuse material
            primitives[i].bsdf.add_diffuse(material.reflectance)
        elif material.material_type==1:
            # Diffuse-Transmission material
            primitives[i].bsdf.add_transmission(material.reflectance, material.transmittance)
        elif material.material_type==2:
            # Dielectric material
            primitives[i].bsdf.add_dielectric(material.eta[0], material.reflectance, material.uroughness, material.vroughness)
        elif material.material_type==3:
            # Conductor material
            print(material.eta)
            primitives[i].bsdf.add_conductor(material.eta, material.k, material.uroughness, material.vroughness)

        if primitives[i].is_light == 1:
            print(i, primitives[i].material.emission)
            light_idx = primitives[i].light_idx
            lights[light_idx].shape_idx = i  # Link the light to the primitive
            lights[light_idx].two_sided = 0  # Assuming lights are one-sided
            lights[light_idx].Le = primitives[i].material.emission
            light_idx += 1

populate_shapes()
# Out:
# 34 [30.000000, 30.000000, 30.000000]
# 35 [30.000000, 30.000000, 30.000000]

# %%
lights.to_numpy()
# Out:
# {'shape_idx': array([34, 35], dtype=int32),
#  'Le': array([[30., 30., 30.],
#         [30., 30., 30.]], dtype=float32),
#  'two_sided': array([0, 0], dtype=int32)}

# %%
from primitives.aabb import AABB, BVHPrimitive

# Enclose all the primitives in their individual axis-aligned bounding boxes (AABB)
BS = ti.root.dense(ti.i, n_primitives)
bvh_primitives = BVHPrimitive.field()
BS.place(bvh_primitives)

scene_min = ti.Vector.field(3, dtype=ti.f32, shape=())  # Global min bounds
scene_max = ti.Vector.field(3, dtype=ti.f32, shape=())  # Global max bounds

@ti.kernel
def init_bounded_boxes():
    # Initialize scene bounding box with extreme values
    scene_min[None] = vec3(1e10, 1e10, 1e10)
    scene_max[None] = vec3(-1e10, -1e10, -1e10)

    for i in ti.ndrange(n_primitives):
        bvh_primitives[i].prim = primitives[i]
        bvh_primitives[i].prim_num = i

        # Get primitive bounds
        min_p, max_p = primitives[i].get_bounds()
        centroid = (min_p + max_p) * 0.5
        bvh_primitives[i].bounds = AABB(min_point=min_p, max_point=max_p, centroid=centroid)

        # Update scene-wide bounding box
        for j in range(3):  # Loop over x, y, z components
            scene_min[None][j] = min(scene_min[None][j], min_p[j])
            scene_max[None][j] = max(scene_max[None][j], max_p[j])


init_bounded_boxes()

bvh_primitives.shape[0], n_primitives
# Out:
# (36, 36)

# %%
OPS = ti.root.dense(ti.i, n_primitives)
ordered_prims = Primitive.field()
OPS.place(ordered_prims)
# Out:
# <ti.SNode of type dense>

# %%
from accelerators.bvh import BVHNode, BucketInfo

node_idx = 0

BVS = ti.root.dense(ti.i, 3 * n_primitives)
nodes = BVHNode.field()
BVS.place(nodes)
# Out:
# <ti.SNode of type dense>

# %%
nodes.shape[0]
# Out:
# 108

# %%
total_nodes = ti.field(ti.i32, shape=())
split_method = ti.field(ti.i32, shape=())
start = ti.field(ti.i32, shape=())
end = ti.field(ti.i32, shape=())
ordered_prims_idx = ti.field(ti.i32, shape=())
stack_ptr = ti.field(ti.i32, shape=())
# ordered_prims_size = ti.field(ti.i32, shape=())

@ti.kernel
def init_stack():
    total_nodes[None] = 0
    split_method[None] = 0
    start[None] = 0
    end[None] = n_primitives
    ordered_prims_idx[None] = 0
    stack_ptr[None] = 0
    # ordered_prims_size[None] = 0

init_stack()

# %%
stack = ti.field(ti.i32, shape=(3*n_primitives, 4))
n_buckets = 12
buckets = BucketInfo.field(shape=(n_buckets))
costs = ti.field(dtype=ti.f32, shape=(n_buckets-1))

# %%
from accelerators.bvh import build_bvh

start_t = time.time()

build_bvh(primitives, bvh_primitives, start, end, ordered_prims, nodes, total_nodes, split_method, stack, stack_ptr, ordered_prims_idx, costs, buckets)

end_t = time.time()

# %%
# total_nodes = ti.field(ti.i32, shape=())
# split_method = ti.field(ti.i32, shape=())
# start = ti.field(ti.i32, shape=())
# end = ti.field(ti.i32, shape=())
# ordered_prims_idx = ti.field(ti.i32, shape=())
# stack_ptr = ti.field(ti.i32, shape=())
# max_prims_in_node = ti.field(ti.i32, shape=())
# # ordered_prims_size = ti.field(ti.i32, shape=())
#
# @ti.kernel
# def init_stack():
#     total_nodes[None] = 0
#     split_method[None] = 0
#     start[None] = 0
#     end[None] = n_primitives
#     ordered_prims_idx[None] = 0
#     stack_ptr[None] = 0
#     max_prims_in_node[None] = 4
#
# init_stack()

# %%
# stack = ti.field(ti.i32, shape=(3*n_primitives, 4))
# n_buckets = 12
# buckets = BucketInfo.field(shape=(n_buckets))
# costs = ti.field(dtype=ti.f32, shape=(n_buckets-1))

# %%
# from accelerators.hlbvh import build_hlbvh
# from accelerators.bvh import build_bvh
#
# start_t = time.time()
#
# root = ti.field(ti.i32, shape=())
#
# build_hlbvh(
#     primitives,
#     bvh_primitives,
#     ordered_prims,
#     n_primitives,       # number of actual primitives
#     nodes,
#     total_nodes,
#     ordered_prims_idx,  # you already have this
#     max_prims_in_node,
#     root
# )
#
# end_t = time.time()

# %%
print("Elapsed (with compilation) = %s" % (end_t - start_t))
print(f"Total Nodes: {total_nodes}")
# Out:
# Elapsed (with compilation) = 0.16219210624694824
# Total Nodes: 57

# %%
from tests.test_bvh import print_bvh

print_bvh(nodes, total_nodes[None])
# Out:
# BVHNode 0 [Interior]: split_axis = 1 child_0 = 1 child_1 = 30 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [1.000000, 1.000000, 7.800000] )
# BVHNode 1 [Interior]: split_axis = 1 child_0 = 2 child_1 = 13 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [1.000000, 1.000000, 7.800000] )
# BVHNode 2 [Interior]: split_axis = 1 child_0 = 3 child_1 = 6 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [1.000000, 1.000000, 7.800000] )
# BVHNode 3 [Interior]: split_axis = 1 child_0 = 4 child_1 = 5 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [1.000000, 1.000000, 7.800000] )
# BVHNode 4 [Leaf]: first_prim_offset = 0 n_primitives = 2 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [1.000000, -1.000000, 7.800000] )
# BVHNode 5 [Leaf]: first_prim_offset = 2 n_primitives = 2 bounds = (min: [-1.000000, 1.000000, 5.800000] , max: [1.000000, 1.000000, 7.800000] )
# BVHNode 6 [Interior]: split_axis = 0 child_0 = 7 child_1 = 8 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [1.000000, 1.000000, 7.800000] )
# BVHNode 7 [Leaf]: first_prim_offset = 4 n_primitives = 2 bounds = (min: [-1.000000, -1.000000, 7.800000] , max: [1.000000, 1.000000, 7.800000] )
# BVHNode 8 [Interior]: split_axis = 0 child_0 = 9 child_1 = 10 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [1.000000, 1.000000, 7.800000] )
# BVHNode 9 [Leaf]: first_prim_offset = 6 n_primitives = 1 bounds = (min: [1.000000, -1.000000, 5.800000] , max: [1.000000, 1.000000, 7.800000] )
# BVHNode 10 [Interior]: split_axis = 0 child_0 = 11 child_1 = 12 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [1.000000, 1.000000, 7.800000] )
# BVHNode 11 [Leaf]: first_prim_offset = 7 n_primitives = 1 bounds = (min: [1.000000, -1.000000, 5.800000] , max: [1.000000, 1.000000, 7.800000] )
# BVHNode 12 [Leaf]: first_prim_offset = 8 n_primitives = 1 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [-1.000000, 1.000000, 7.800000] )
# BVHNode 13 [Interior]: split_axis = 1 child_0 = 14 child_1 = 21 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [0.128366, 1.000000, 7.800000] )
# BVHNode 14 [Interior]: split_axis = 0 child_0 = 15 child_1 = 18 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [0.128366, 1.000000, 7.800000] )
# BVHNode 15 [Interior]: split_axis = 1 child_0 = 16 child_1 = 17 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [-0.343717, 1.000000, 7.800000] )
# BVHNode 16 [Leaf]: first_prim_offset = 9 n_primitives = 1 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [-1.000000, 1.000000, 7.800000] )
# BVHNode 17 [Leaf]: first_prim_offset = 10 n_primitives = 1 bounds = (min: [-0.715132, -1.000000, 6.525123] , max: [-0.343717, -0.400000, 6.989721] )
# BVHNode 18 [Interior]: split_axis = 0 child_0 = 19 child_1 = 20 bounds = (min: [-0.715132, -1.000000, 6.147724] , max: [0.128366, -0.400000, 6.989721] )
# BVHNode 19 [Leaf]: first_prim_offset = 11 n_primitives = 1 bounds = (min: [-0.715132, -1.000000, 6.525123] , max: [-0.343717, -0.400000, 6.989721] )
# BVHNode 20 [Leaf]: first_prim_offset = 12 n_primitives = 1 bounds = (min: [-0.243048, -1.000000, 6.147724] , max: [0.128366, -0.400000, 6.612322] )
# BVHNode 21 [Interior]: split_axis = 1 child_0 = 22 child_1 = 25 bounds = (min: [-0.715132, -1.000000, 6.147724] , max: [0.128366, -0.400000, 6.989721] )
# BVHNode 22 [Interior]: split_axis = 0 child_0 = 23 child_1 = 24 bounds = (min: [-0.715132, -1.000000, 6.147724] , max: [0.128366, -0.400000, 6.989721] )
# BVHNode 23 [Leaf]: first_prim_offset = 13 n_primitives = 1 bounds = (min: [-0.243048, -1.000000, 6.147724] , max: [0.128366, -0.400000, 6.612322] )
# BVHNode 24 [Leaf]: first_prim_offset = 14 n_primitives = 1 bounds = (min: [-0.715132, -0.400000, 6.147724] , max: [-0.243048, -0.400000, 6.989721] )
# BVHNode 25 [Interior]: split_axis = 1 child_0 = 26 child_1 = 27 bounds = (min: [-0.715132, -1.000000, 6.147724] , max: [0.128366, -0.400000, 6.989721] )
# BVHNode 26 [Leaf]: first_prim_offset = 15 n_primitives = 1 bounds = (min: [-0.343717, -0.400000, 6.147724] , max: [0.128366, -0.400000, 6.989721] )
# BVHNode 27 [Interior]: split_axis = 2 child_0 = 28 child_1 = 29 bounds = (min: [-0.715132, -1.000000, 6.147724] , max: [0.128366, -1.000000, 6.989721] )
# BVHNode 28 [Leaf]: first_prim_offset = 16 n_primitives = 1 bounds = (min: [-0.715132, -1.000000, 6.525123] , max: [0.128366, -1.000000, 6.989721] )
# BVHNode 29 [Leaf]: first_prim_offset = 17 n_primitives = 1 bounds = (min: [-0.715132, -1.000000, 6.147724] , max: [0.128366, -1.000000, 6.612322] )
# BVHNode 30 [Interior]: split_axis = 1 child_0 = 31 child_1 = 42 bounds = (min: [-0.715132, -1.000000, 6.147724] , max: [0.818910, 0.980000, 7.351282] )
# BVHNode 31 [Interior]: split_axis = 0 child_0 = 32 child_1 = 35 bounds = (min: [-0.715132, -1.000000, 6.147724] , max: [0.818910, 0.200000, 7.351282] )
# BVHNode 32 [Interior]: split_axis = 2 child_0 = 33 child_1 = 34 bounds = (min: [-0.715132, -1.000000, 6.147724] , max: [0.128366, -0.400000, 6.989721] )
# BVHNode 33 [Leaf]: first_prim_offset = 18 n_primitives = 2 bounds = (min: [-0.715132, -1.000000, 6.147724] , max: [-0.243048, -0.400000, 6.525123] )
# BVHNode 34 [Leaf]: first_prim_offset = 20 n_primitives = 2 bounds = (min: [-0.343717, -1.000000, 6.612322] , max: [0.128366, -0.400000, 6.989721] )
# BVHNode 35 [Interior]: split_axis = 1 child_0 = 36 child_1 = 37 bounds = (min: [-0.019314, -1.000000, 6.515592] , max: [0.818910, 0.200000, 7.351282] )
# BVHNode 36 [Leaf]: first_prim_offset = 22 n_primitives = 2 bounds = (min: [-0.019314, -1.000000, 7.010040] , max: [0.483035, 0.200000, 7.351282] )
# BVHNode 37 [Interior]: split_axis = 1 child_0 = 38 child_1 = 39 bounds = (min: [-0.019314, -1.000000, 6.515592] , max: [0.818910, 0.200000, 7.351282] )
# BVHNode 38 [Leaf]: first_prim_offset = 24 n_primitives = 1 bounds = (min: [0.316561, -1.000000, 6.515592] , max: [0.818910, 0.200000, 6.856834] )
# BVHNode 39 [Interior]: split_axis = 1 child_0 = 40 child_1 = 41 bounds = (min: [-0.019314, -1.000000, 6.515592] , max: [0.818910, 0.200000, 7.351282] )
# BVHNode 40 [Leaf]: first_prim_offset = 25 n_primitives = 1 bounds = (min: [0.316561, -1.000000, 6.515592] , max: [0.818910, 0.200000, 6.856834] )
# BVHNode 41 [Leaf]: first_prim_offset = 26 n_primitives = 1 bounds = (min: [-0.019314, 0.200000, 6.515592] , max: [0.483035, 0.200000, 7.351282] )
# BVHNode 42 [Interior]: split_axis = 1 child_0 = 43 child_1 = 50 bounds = (min: [-0.240000, -1.000000, 6.515592] , max: [0.818910, 0.980000, 7.351282] )
# BVHNode 43 [Interior]: split_axis = 1 child_0 = 44 child_1 = 47 bounds = (min: [-0.019314, -1.000000, 6.515592] , max: [0.818910, 0.200000, 7.351282] )
# BVHNode 44 [Interior]: split_axis = 1 child_0 = 45 child_1 = 46 bounds = (min: [-0.019314, -1.000000, 6.515592] , max: [0.818910, 0.200000, 7.351282] )
# BVHNode 45 [Leaf]: first_prim_offset = 27 n_primitives = 1 bounds = (min: [0.316561, 0.200000, 6.515592] , max: [0.818910, 0.200000, 7.351282] )
# BVHNode 46 [Leaf]: first_prim_offset = 28 n_primitives = 1 bounds = (min: [-0.019314, -1.000000, 6.856834] , max: [0.818910, -1.000000, 7.351282] )
# BVHNode 47 [Interior]: split_axis = 1 child_0 = 48 child_1 = 49 bounds = (min: [-0.019314, -1.000000, 6.515592] , max: [0.818910, 0.200000, 7.010040] )
# BVHNode 48 [Leaf]: first_prim_offset = 29 n_primitives = 1 bounds = (min: [-0.019314, -1.000000, 6.515592] , max: [0.818910, -1.000000, 7.010040] )
# BVHNode 49 [Leaf]: first_prim_offset = 30 n_primitives = 1 bounds = (min: [-0.019314, -1.000000, 6.515592] , max: [0.316561, 0.200000, 7.010040] )
# BVHNode 50 [Interior]: split_axis = 1 child_0 = 51 child_1 = 54 bounds = (min: [-0.240000, -1.000000, 6.515592] , max: [0.818910, 0.980000, 7.351282] )
# BVHNode 51 [Interior]: split_axis = 0 child_0 = 52 child_1 = 53 bounds = (min: [-0.019314, -1.000000, 6.515592] , max: [0.818910, 0.200000, 7.351282] )
# BVHNode 52 [Leaf]: first_prim_offset = 31 n_primitives = 1 bounds = (min: [-0.019314, -1.000000, 6.515592] , max: [0.316561, 0.200000, 7.010040] )
# BVHNode 53 [Leaf]: first_prim_offset = 32 n_primitives = 1 bounds = (min: [0.483035, -1.000000, 6.856834] , max: [0.818910, 0.200000, 7.351282] )
# BVHNode 54 [Interior]: split_axis = 1 child_0 = 55 child_1 = 56 bounds = (min: [-0.240000, -1.000000, 6.640000] , max: [0.818910, 0.980000, 7.351282] )
# BVHNode 55 [Leaf]: first_prim_offset = 33 n_primitives = 1 bounds = (min: [0.483035, -1.000000, 6.856834] , max: [0.818910, 0.200000, 7.351282] )
# BVHNode 56 [Leaf]: first_prim_offset = 34 n_primitives = 2 bounds = (min: [-0.240000, 0.980000, 6.640000] , max: [0.230000, 0.980000, 7.020000] )

# %%
from tests.test_bvh import test_bvh
max_nodes = n_primitives
debug_stack = ti.field(dtype=ti.i32, shape=(max_nodes,))
debug_ptr = ti.field(dtype=ti.i32, shape=(1,))
error_count = ti.field(dtype=ti.i32, shape=(1,))

test_bvh(nodes, debug_stack, debug_ptr, error_count)
# Out:
# BVH test error count = 0

# %%
from accelerators.bvh import LinearBVHNode
from accelerators.bvh import flatten_bvh

# create a linear representation of the bvh tree (empty)

LBVS = ti.root.dense(ti.i, total_nodes[None])
linear_bvh = LinearBVHNode.field()
LBVS.place(linear_bvh)

stack_size = 2 * n_primitives - 1  # Maximum possible stack size
stack3 = ti.Vector.field(3, dtype=ti.i32, shape=stack_size)
stack_top_2 = ti.field(dtype=ti.i32, shape=())

start_t = time.time()
total_nodes = flatten_bvh(nodes, linear_bvh, 0, stack3, stack_top_2)
end_t = time.time()
print(f"Total flattened nodes: {total_nodes}")
# Out:
# Total flattened nodes: 57

# %%
linear_bvh[0].second_child_offset
# Out:
# 30

# %%
print("Elapsed (with compilation) = %s" % (end_t - start_t))
# Out:
# Elapsed (with compilation) = 0.020463943481445312

# %%
from tests.test_linear_bvh import print_flattened_bvh

print_flattened_bvh(linear_bvh, total_nodes)
# Out:
# LinearBVHNode 0 [Interior]: axis = 1 second_child_offset = 30 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [1.000000, 1.000000, 7.800000] )
# LinearBVHNode 1 [Interior]: axis = 1 second_child_offset = 13 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [1.000000, 1.000000, 7.800000] )
# LinearBVHNode 2 [Interior]: axis = 1 second_child_offset = 6 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [1.000000, 1.000000, 7.800000] )
# LinearBVHNode 3 [Interior]: axis = 1 second_child_offset = 5 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [1.000000, 1.000000, 7.800000] )
# LinearBVHNode 4 [Leaf]: primitives_offset = 0 n_primitives = 2 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [1.000000, -1.000000, 7.800000] )
# LinearBVHNode 5 [Leaf]: primitives_offset = 2 n_primitives = 2 bounds = (min: [-1.000000, 1.000000, 5.800000] , max: [1.000000, 1.000000, 7.800000] )
# LinearBVHNode 6 [Interior]: axis = 0 second_child_offset = 8 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [1.000000, 1.000000, 7.800000] )
# LinearBVHNode 7 [Leaf]: primitives_offset = 4 n_primitives = 2 bounds = (min: [-1.000000, -1.000000, 7.800000] , max: [1.000000, 1.000000, 7.800000] )
# LinearBVHNode 8 [Interior]: axis = 0 second_child_offset = 10 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [1.000000, 1.000000, 7.800000] )
# LinearBVHNode 9 [Leaf]: primitives_offset = 6 n_primitives = 1 bounds = (min: [1.000000, -1.000000, 5.800000] , max: [1.000000, 1.000000, 7.800000] )
# LinearBVHNode 10 [Interior]: axis = 0 second_child_offset = 12 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [1.000000, 1.000000, 7.800000] )
# LinearBVHNode 11 [Leaf]: primitives_offset = 7 n_primitives = 1 bounds = (min: [1.000000, -1.000000, 5.800000] , max: [1.000000, 1.000000, 7.800000] )
# LinearBVHNode 12 [Leaf]: primitives_offset = 8 n_primitives = 1 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [-1.000000, 1.000000, 7.800000] )
# LinearBVHNode 13 [Interior]: axis = 1 second_child_offset = 21 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [0.128366, 1.000000, 7.800000] )
# LinearBVHNode 14 [Interior]: axis = 0 second_child_offset = 18 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [0.128366, 1.000000, 7.800000] )
# LinearBVHNode 15 [Interior]: axis = 1 second_child_offset = 17 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [-0.343717, 1.000000, 7.800000] )
# LinearBVHNode 16 [Leaf]: primitives_offset = 9 n_primitives = 1 bounds = (min: [-1.000000, -1.000000, 5.800000] , max: [-1.000000, 1.000000, 7.800000] )
# LinearBVHNode 17 [Leaf]: primitives_offset = 10 n_primitives = 1 bounds = (min: [-0.715132, -1.000000, 6.525123] , max: [-0.343717, -0.400000, 6.989721] )
# LinearBVHNode 18 [Interior]: axis = 0 second_child_offset = 20 bounds = (min: [-0.715132, -1.000000, 6.147724] , max: [0.128366, -0.400000, 6.989721] )
# LinearBVHNode 19 [Leaf]: primitives_offset = 11 n_primitives = 1 bounds = (min: [-0.715132, -1.000000, 6.525123] , max: [-0.343717, -0.400000, 6.989721] )
# LinearBVHNode 20 [Leaf]: primitives_offset = 12 n_primitives = 1 bounds = (min: [-0.243048, -1.000000, 6.147724] , max: [0.128366, -0.400000, 6.612322] )
# LinearBVHNode 21 [Interior]: axis = 1 second_child_offset = 25 bounds = (min: [-0.715132, -1.000000, 6.147724] , max: [0.128366, -0.400000, 6.989721] )
# LinearBVHNode 22 [Interior]: axis = 0 second_child_offset = 24 bounds = (min: [-0.715132, -1.000000, 6.147724] , max: [0.128366, -0.400000, 6.989721] )
# LinearBVHNode 23 [Leaf]: primitives_offset = 13 n_primitives = 1 bounds = (min: [-0.243048, -1.000000, 6.147724] , max: [0.128366, -0.400000, 6.612322] )
# LinearBVHNode 24 [Leaf]: primitives_offset = 14 n_primitives = 1 bounds = (min: [-0.715132, -0.400000, 6.147724] , max: [-0.243048, -0.400000, 6.989721] )
# LinearBVHNode 25 [Interior]: axis = 1 second_child_offset = 27 bounds = (min: [-0.715132, -1.000000, 6.147724] , max: [0.128366, -0.400000, 6.989721] )
# LinearBVHNode 26 [Leaf]: primitives_offset = 15 n_primitives = 1 bounds = (min: [-0.343717, -0.400000, 6.147724] , max: [0.128366, -0.400000, 6.989721] )
# LinearBVHNode 27 [Interior]: axis = 2 second_child_offset = 29 bounds = (min: [-0.715132, -1.000000, 6.147724] , max: [0.128366, -1.000000, 6.989721] )
# LinearBVHNode 28 [Leaf]: primitives_offset = 16 n_primitives = 1 bounds = (min: [-0.715132, -1.000000, 6.525123] , max: [0.128366, -1.000000, 6.989721] )
# LinearBVHNode 29 [Leaf]: primitives_offset = 17 n_primitives = 1 bounds = (min: [-0.715132, -1.000000, 6.147724] , max: [0.128366, -1.000000, 6.612322] )
# LinearBVHNode 30 [Interior]: axis = 1 second_child_offset = 42 bounds = (min: [-0.715132, -1.000000, 6.147724] , max: [0.818910, 0.980000, 7.351282] )
# LinearBVHNode 31 [Interior]: axis = 0 second_child_offset = 35 bounds = (min: [-0.715132, -1.000000, 6.147724] , max: [0.818910, 0.200000, 7.351282] )
# LinearBVHNode 32 [Interior]: axis = 2 second_child_offset = 34 bounds = (min: [-0.715132, -1.000000, 6.147724] , max: [0.128366, -0.400000, 6.989721] )
# LinearBVHNode 33 [Leaf]: primitives_offset = 18 n_primitives = 2 bounds = (min: [-0.715132, -1.000000, 6.147724] , max: [-0.243048, -0.400000, 6.525123] )
# LinearBVHNode 34 [Leaf]: primitives_offset = 20 n_primitives = 2 bounds = (min: [-0.343717, -1.000000, 6.612322] , max: [0.128366, -0.400000, 6.989721] )
# LinearBVHNode 35 [Interior]: axis = 1 second_child_offset = 37 bounds = (min: [-0.019314, -1.000000, 6.515592] , max: [0.818910, 0.200000, 7.351282] )
# LinearBVHNode 36 [Leaf]: primitives_offset = 22 n_primitives = 2 bounds = (min: [-0.019314, -1.000000, 7.010040] , max: [0.483035, 0.200000, 7.351282] )
# LinearBVHNode 37 [Interior]: axis = 1 second_child_offset = 39 bounds = (min: [-0.019314, -1.000000, 6.515592] , max: [0.818910, 0.200000, 7.351282] )
# LinearBVHNode 38 [Leaf]: primitives_offset = 24 n_primitives = 1 bounds = (min: [0.316561, -1.000000, 6.515592] , max: [0.818910, 0.200000, 6.856834] )
# LinearBVHNode 39 [Interior]: axis = 1 second_child_offset = 41 bounds = (min: [-0.019314, -1.000000, 6.515592] , max: [0.818910, 0.200000, 7.351282] )
# LinearBVHNode 40 [Leaf]: primitives_offset = 25 n_primitives = 1 bounds = (min: [0.316561, -1.000000, 6.515592] , max: [0.818910, 0.200000, 6.856834] )
# LinearBVHNode 41 [Leaf]: primitives_offset = 26 n_primitives = 1 bounds = (min: [-0.019314, 0.200000, 6.515592] , max: [0.483035, 0.200000, 7.351282] )
# LinearBVHNode 42 [Interior]: axis = 1 second_child_offset = 50 bounds = (min: [-0.240000, -1.000000, 6.515592] , max: [0.818910, 0.980000, 7.351282] )
# LinearBVHNode 43 [Interior]: axis = 1 second_child_offset = 47 bounds = (min: [-0.019314, -1.000000, 6.515592] , max: [0.818910, 0.200000, 7.351282] )
# LinearBVHNode 44 [Interior]: axis = 1 second_child_offset = 46 bounds = (min: [-0.019314, -1.000000, 6.515592] , max: [0.818910, 0.200000, 7.351282] )
# LinearBVHNode 45 [Leaf]: primitives_offset = 27 n_primitives = 1 bounds = (min: [0.316561, 0.200000, 6.515592] , max: [0.818910, 0.200000, 7.351282] )
# LinearBVHNode 46 [Leaf]: primitives_offset = 28 n_primitives = 1 bounds = (min: [-0.019314, -1.000000, 6.856834] , max: [0.818910, -1.000000, 7.351282] )
# LinearBVHNode 47 [Interior]: axis = 1 second_child_offset = 49 bounds = (min: [-0.019314, -1.000000, 6.515592] , max: [0.818910, 0.200000, 7.010040] )
# LinearBVHNode 48 [Leaf]: primitives_offset = 29 n_primitives = 1 bounds = (min: [-0.019314, -1.000000, 6.515592] , max: [0.818910, -1.000000, 7.010040] )
# LinearBVHNode 49 [Leaf]: primitives_offset = 30 n_primitives = 1 bounds = (min: [-0.019314, -1.000000, 6.515592] , max: [0.316561, 0.200000, 7.010040] )
# LinearBVHNode 50 [Interior]: axis = 1 second_child_offset = 54 bounds = (min: [-0.240000, -1.000000, 6.515592] , max: [0.818910, 0.980000, 7.351282] )
# LinearBVHNode 51 [Interior]: axis = 0 second_child_offset = 53 bounds = (min: [-0.019314, -1.000000, 6.515592] , max: [0.818910, 0.200000, 7.351282] )
# LinearBVHNode 52 [Leaf]: primitives_offset = 31 n_primitives = 1 bounds = (min: [-0.019314, -1.000000, 6.515592] , max: [0.316561, 0.200000, 7.010040] )
# LinearBVHNode 53 [Leaf]: primitives_offset = 32 n_primitives = 1 bounds = (min: [0.483035, -1.000000, 6.856834] , max: [0.818910, 0.200000, 7.351282] )
# LinearBVHNode 54 [Interior]: axis = 1 second_child_offset = 56 bounds = (min: [-0.240000, -1.000000, 6.640000] , max: [0.818910, 0.980000, 7.351282] )
# LinearBVHNode 55 [Leaf]: primitives_offset = 33 n_primitives = 1 bounds = (min: [0.483035, -1.000000, 6.856834] , max: [0.818910, 0.200000, 7.351282] )
# LinearBVHNode 56 [Leaf]: primitives_offset = 34 n_primitives = 2 bounds = (min: [-0.240000, 0.980000, 6.640000] , max: [0.230000, 0.980000, 7.020000] )

# %%
from tests.test_linear_bvh import test_flattened_bvh

max_nodes = n_primitives
debug_stack = ti.field(dtype=ti.i32, shape=(max_nodes,))
debug_ptr = ti.field(dtype=ti.i32, shape=(1,))
error_count = ti.field(dtype=ti.i32, shape=(1,))

test_flattened_bvh(linear_bvh, debug_stack, debug_ptr, error_count)
# Out:
# Flattened BVH test error count = 0

# %%
# Parse Camera Data

camera_data = scene_dict["Camera"][0]["properties"]
camera_data
# Out:
# {'fov': [19.5]}

# %%
scene_min[None], scene_max[None]
# Out:
# ([-1.         -1.00000012  5.80000019], [1.         1.         7.80000019])

# %%
from pbrt.camera_parser import extract_camera_from_scene
from base.camera import auto_fit_camera, get_camera

eye, center, up, fov = extract_camera_from_scene(scene_dict)

# camera = auto_fit_camera(scene_min[None], scene_max[None], fov, 400, 400, 0)
camera = get_camera(eye, center, up, fov, 512, 512)
# Out:
# Extracted Camera Parameters: [-0.000000, -0.000000, -0.000000] [0.000000, 0.000000, 1.000000] [-0.000000, 1.000000, -0.000000] 19.500000
# [-0.000000, -0.000000, -0.000000] [0.000000, 0.000000, 1.000000] [-0.000000, 1.000000, -0.000000]
# /Volumes/extssd/Projects/light-transport-simulator/.venv/lib/python3.13/site-packages/taichi/lang/ast/ast_transformer.py:1664: DeprecationWarning: ast.Str is deprecated and will be removed in Python 3.14; use ast.Constant instead
#   elif isinstance(node.msg, ast.Str):

# %%
camera
# Out:
# {'width': 512, 'height': 512, 'position': [-0.0, -0.0, -0.0], 'frame': {'x': [1.0, 0.0, -0.0], 'y': [-0.0, 1.0, 0.0], 'z': [-0.0, -0.0, -1.0]}, 'fov': 19.5, 'aspect_ratio': 1.0, 'lens_radius': 0.0, 'focal_distance': 1.0, 'screen_window': [-0.1718314290046692, 0.1718314290046692, -0.1718314290046692, 0.1718314290046692], 'dx_camera': [0.000671216519549489, 0.0, 0.0], 'dy_camera': [0.0, 0.000671216519549489, 0.0]}

# %%
scene_min[None], scene_max[None]
# Out:
# ([-1.         -1.00000012  5.80000019], [1.         1.         7.80000019])

# %%
camera.frame
# Out:
# {'x': [1.0, 0.0, -0.0], 'y': [-0.0, 1.0, 0.0], 'z': [-0.0, -0.0, -1.0]}

# %%
@ti.kernel
def test_camera():
    # Generate a ray
    s, t = 0.5, 0.5  # Center of the screen
    ray_origin, ray_dir, rx_origin, rx_dir, ry_origin, ry_dir = camera.generate_ray_differential(s, t)
    print(ray_origin, ray_dir, rx_origin, rx_dir, ry_origin, ry_dir)

test_camera()
# Out:
# [0.000000, 0.000000, 0.000000] [0.000000, 0.000000, 1.000000] [0.000000, 0.000000, 0.000000] [0.000671, 0.000000, 1.000000] [0.000000, 0.000000, 0.000000] [0.000000, 0.000671, 1.000000]

# %%
from base.scene import Scene

pt = 0
mis = 1

# Instantiate a Scene object with the Camera object
scene = Scene(integrator=mis, spp=256, max_depth=7, sample_lights=1, sample_bsdf=1)

# %%
from base.render import render

# Initialize the image field outside the kernel using the actual values
image = ti.Vector.field(3, dtype=ti.f32, shape=(camera.width, camera.height))


start_t = time.time()

# Call the render_scene kernel
render(scene, image, lights, camera, ordered_prims, linear_bvh)

end_t = time.time()

print("Elapsed (with compilation) = %s" % (end_t - start_t))
# Out:
# Elapsed (with compilation) = 235.1472201347351

# %%
image_np = image.to_numpy()
# if np.isnan(image_np).any() or np.isinf(image_np).any():
#     print("Warning: NaN or Inf values detected in the image")
# image_np = np.clip(image_np, 0, 1)  # Clip values between 0 and 1
plt.imshow(image_np)
plt.axis('off')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.00052412413..30.406904].

# %%
def tone_mapping(hdr_image, gamma=2.2):
    ldr_image = hdr_image / (1.0 + hdr_image)
    ldr_image = np.power(ldr_image, 1.0 / gamma)
    return np.clip(ldr_image, 0, 1)

ldr_image = tone_mapping(image_np)

# Display the tone-mapped image
plt.imshow(ldr_image)
plt.axis('off')
plt.show()
